# %% [markdown]
# <a href="https://colab.research.google.com/github/The-DarkBeast/Humanless-Parking/blob/me%2Fdeep-anpr/deep-anpr-setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/matthewearl/deep-anpr
# Out:
# Cloning into 'deep-anpr'...
# remote: Enumerating objects: 150, done.
# remote: Total 150 (delta 0), reused 0 (delta 0), pack-reused 150
# Receiving objects: 100% (150/150), 43.13 KiB | 1.96 MiB/s, done.
# Resolving deltas: 100% (89/89), done.

# %%
# !cd deep-anpr/ && wget http://vision.princeton.edu/projects/2010/SUN/SUN397.tar.gz
# Out:
# --2020-01-18 11:55:04--  http://vision.princeton.edu/projects/2010/SUN/SUN397.tar.gz
# Resolving vision.princeton.edu (vision.princeton.edu)... 128.112.136.51
# Connecting to vision.princeton.edu (vision.princeton.edu)|128.112.136.51|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://vision.princeton.edu/projects/2010/SUN/SUN397.tar.gz [following]
# --2020-01-18 11:55:04--  https://vision.princeton.edu/projects/2010/SUN/SUN397.tar.gz
# Connecting to vision.princeton.edu (vision.princeton.edu)|128.112.136.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39077296924 (36G) [application/x-gzip]
# Saving to: ‘SUN397.tar.gz’
#
# SUN397.tar.gz       100%[===================>]  36.39G  62.8MB/s    in 10m 29s
#
# 2020-01-18 12:05:34 (59.2 MB/s) - ‘SUN397.tar.gz’ saved [39077296924/39077296924]

# %%
# !cd deep-anpr/ && sed -i "s|print fname|print(fname)|g" extractbgs.py

# %%
# !cd deep-anpr/ && sed -i "s|return cv2.imdecode(a, cv2.CV_LOAD_IMAGE_GRAYSCALE)|return cv2.imdecode(a, 0)|g" extractbgs.py

# %%
# !cd deep-anpr/ && ls && rm -r bgs
# Out:
# bgs	   detect.py	  gen.py   model.py   SUN397.tar.gz  vis.py
# common.py  extractbgs.py  LICENSE  README.md  train.py

# %%
# !cd deep-anpr/ && ./extractbgs.py SUN397.tar.gz
# Out:
# bgs/00000000.jpg
# bgs/00000001.jpg
# bgs/00000002.jpg
# bgs/00000003.jpg
# bgs/00000004.jpg
# bgs/00000005.jpg
# bgs/00000006.jpg
# bgs/00000007.jpg
# bgs/00000008.jpg
# bgs/00000009.jpg
# bgs/00000010.jpg
# bgs/00000011.jpg
# bgs/00000012.jpg
# bgs/00000013.jpg
# bgs/00000014.jpg
# bgs/00000015.jpg
# bgs/00000016.jpg
# bgs/00000017.jpg
# bgs/00000018.jpg
# bgs/00000019.jpg
# bgs/00000020.jpg
# bgs/00000021.jpg
# bgs/00000022.jpg
# bgs/00000023.jpg
# bgs/00000024.jpg
# bgs/00000025.jpg
# bgs/00000026.jpg
# bgs/00000027.jpg
# bgs/00000028.jpg
# bgs/00000029.jpg
# bgs/00000030.jpg
# bgs/00000031.jpg
# bgs/00000032.jpg
# bgs/00000033.jpg
# bgs/00000034.jpg
# bgs/00000035.jpg
# bgs/00000036.jpg
# bgs/00000037.jpg
# bgs/00000038.jpg
# bgs/00000039.jpg
# bgs/00000040.jpg
# bgs/00000041.jpg
# bgs/00000042.jpg
# bgs/00000043.jpg
# bgs/00000044.jpg
# bgs/00000045.jpg
# bgs/00000046.jpg
# bgs/00000047.jpg
# bgs/00000048.jpg
# bgs/00000049.jpg
# bgs/00000050.jpg
# bgs/00000051.jpg
# ...
